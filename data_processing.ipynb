# %%
import pandas as pd

# %%
df = pd.read_csv("data/DS2003_NBA_Data.csv")
# Out:
# /var/folders/rw/kqv4w2bj5hx2v1ln61zfm4pr0000gn/T/ipykernel_59530/619131225.py:1: DtypeWarning: Columns (4,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/DS2003_NBA_Data.csv")

# %%
df
# Out:
#            GameDay   GameID           Player  PlayerID  \
# 0       2003-10-29    16560     LeBron James      1871
# 1       2003-10-30    16565     LeBron James      1871
# 2       2003-11-01    16585     LeBron James      1871
# 3       2003-11-05    16600     LeBron James      1871
# 4       2003-11-07    16618     LeBron James      1871
# ...            ...      ...              ...       ...
# 172540  2024-06-17  1079270    Dwight Powell      3110
# 172541  2024-06-17  1079270  Tim Hardaway Jr  43357004
# 172542  2024-06-17  1079270   Daniel Gafford   1258511
# 172543  2024-06-17  1079270    Derrick Jones    119696
# 172544  2024-06-17  1079270     Kyrie Irving      1825
#
#                     PlayerCode  TeamID       Team  OpponentID    Opponent  \
# 0                 lebron-james       9  Cleveland          15  Sacramento
# 1                 lebron-james       9  Cleveland          14     Phoenix
# 2                 lebron-james       9  Cleveland           4    Portland
# ...
